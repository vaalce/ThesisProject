# %%
import json

# %%
import pandas

# %%
import requests

# %%
r=requests.get(url='https://tie.digitraffic.fi/api/v1/metadata/tms-stations?lastUpdated=false&state=active')

# %%
print(r.json())
# Out:
# {'type': 'FeatureCollection', 'dataUpdatedTime': '2019-03-22T13:05:09Z', 'dataLastCheckedTime': '2019-03-22T13:05:09Z', 'features': [{'type': 'Feature', 'id': 23001, 'geometry': {'type': 'Point', 'coordinates': [25.689528526505185, 60.41700181416823, 0.0]}, 'properties': {'roadStationId': 23001, 'tmsNumber': 1, 'name': 'vt7_Rita', 'collectionInterval': 0, 'collectionStatus': 'GATHERING', 'municipality': 'Porvoo', 'municipalityCode': '638', 'province': 'Uusimaa', 'provinceCode': '1', 'names': {'fi': 'Tie 7 Porvoo, Rita', 'sv': 'Väg 7 Borgå, Rita', 'en': 'Road 7 Porvoo, Rita'}, 'roadAddress': {'roadNumber': 7, 'roadSection': 10, 'distanceFromRoadSectionStart': 950, 'carriagewayCode': 1, 'roadMaintenanceClass': '1', 'contractArea': 'Porvoo 15 -20', 'contractAreaCode': 133, 'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'}, 'liviId': 'Livi968639', 'country': None, 'startTime': '2001-11-06T22:00:00Z', 'repairMaintenanceTime': '2018-11-29T13:58:30Z', 'annualMaintenanceTime': '2018-10-18T21:00:00Z', 'state': 'OK', 'purpose': 'reaaliaika', 'coordinatesETRS89': [427830.0, 6698571.0, 0.0], 'direction1Municipality': 'Kotka', 'direction1MunicipalityCode': 285, 'direction2Municipality': 'Helsinki', 'direction2MunicipalityCode': 91, 'calculatorDeviceType': None, 'stationSensors': [5054, 5055, 5056, 5057, 5058, 5061, 5064, 5067, 5068, 5071, 5116, 5119, 5122, 5125, 5158, 5161, 5164, 5168], 'tmsStationType': 'DSL_4'}}, {'type': 'Feature', 'id': 23003, 'geometry': {'type': 'Point', 'coordinates': [24.664458755024924, 60.15350217940352, 0.0]}, 'properties': {'roadStationId': 23003, 'tmsNumber': 3, 'name': 'kt51_Kivenlahti', 'collectionInterval': 300, 'collectionStatus': 'GATHERING', 'municipality': 'Espoo', 'municipalityCode': '49', 'province': 'Uusimaa', 'provinceCode': '1', 'names': {'fi': 'Tie 51 Espoo, Kivenlahti', 'sv': 'Väg 51 Esbo, Stensvik', 'en': 'Road 51 Espoo, Kivenlahti'}, 'roadAddress': {'roadNumber': 51, 'roadSection': 6, 'distanceFromRoadSectionStart': 2385, 'carriagewayCode': 1, 'roadMaintenanceClass': '1', 'contractArea': 'Espoo 14-19', 'contractAreaCode': 130, 'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'}, 'liviId': 'Livi1011683', 'country': None, 'startTime': '2016-05-15T21:00:00Z', 'repairMaintenanceTime': '2019-01-04T08:21:52Z', 'annualMaintenanceTime': '2018-09-02T21:00:00Z', 'state': 'REPAIR_MAINTENANCE_DONE', 'purpose': 'ajantasa', 'coordinatesETRS89': [370351.0, 6670799.0, 0.0], 'direction1Municipality': 'Kirkkonummi', 'direction1MunicipalityCode': 257, 'direction2Municipality': 'Helsinki', 'direction2MunicipalityCode': 91, 'calculatorDeviceType': None, 'stationSensors': [5054, 5055, 5056, 5057, 5058, 5061, 5064, 5067, 5068, 5071, 5116, 5119, 5122, 5125, 5158, 5161, 5164, 5168], 'tmsStationType': 'DSL_6'}}, {'type': 'Feature', 'id': 23004, 'geometry': {'type': 'Point', 'coordinates': [24.84950085238505, 60.30000012018926, 0.0]}, 'properties': {'roadStationId': 23004, 'tmsNumber': 4, 'name': 'vt3_Kivistö', 'collectionInterval': 0, 'collectionStatus': 'GATHERING', 'municipality': 'Vantaa', 'municipalityCode': '92', 'province': 'Uusimaa', 'provinceCode': '1', 'names': {'fi': 'L_vt3_Kivistö'}, 'roadAddress': {'roadNumber': 3, 'roadSection': 103, 'distanceFromRoadSectionStart': 913}, 'liviId': None, 'country': None, 'startTime': '2015-08-06T21:00:00Z', 'repairMaintenanceTime': None, 'annualMaintenanceTime': '2018-09-26T21:00:00Z', 'state': 'OK_FAULT_DOUBT_CANCELLED', 'purpose': 'reaaliaika', 'coordinatesETRS89': [381152.0, 6686760.0, 0.0], 'direction1Municipality': 'Hämeenlinna', 'direction1MunicipalityCode': 109, 'direction2Municipality': 'Helsinki', 'direction2MunicipalityCode': 91, 'calculatorDeviceType': None, 'stationSensors': [5054, 5055, 5056, 5057, 5058, 5061, 5064, 5067, 5068, 5071, 5116, 5119, 5122, 5125, 5158, 5161, 5164, 5168], 'tmsStationType': 'DSL_4'}}, {'type': 'Feature', 'id': 23005, 'geometry': {'type': 'Point', 'coordinates': [24.808790916505338, 60.35465602687128, 0.0]}, 'properti ...

# %%
stations = r.json()
counter = 0
tms_stations = {}

for i in stations['features']:
    if i['properties']['municipalityCode'] == '405':
        tms_stations[i['id']] = {"Timestamp": stations["dataUpdatedTime"],
                          "roadStationId": i["properties"]
                         }

# %%
tms_stations
# Out:
# {23306: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23306,
#    'tmsNumber': 306,
#    'name': 'vt13_Nuijamaa_Uusi',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Nuijamaa',
#     'sv': 'Väg 13 Nuijamaa',
#     'en': 'Road 13 Nuijamaa'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 6586,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi1040842',
#    'country': None,
#    'startTime': '2015-08-10T21:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2017-08-29T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'ajantasa',
#    'coordinatesETRS89': [582334.0, 6758729.0, 0.0],
#    'direction1Municipality': None,
#    'direction1MunicipalityCode': 1002,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23533: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23533,
#    'tmsNumber': 533,
#    'name': 'vt13_Karhusjärvi',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Karhusjärvi',
#     'sv': 'Väg 13 Karhusjärvi',
#     'en': 'Road 13 Karhusjärvi'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 240,
#     'distanceFromRoadSectionStart': 391,
#     'carriagewayCode': 0,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'Livi154360',
#    'country': None,
#    'startTime': '1998-09-01T21:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2017-08-29T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'ajantasa',
#    'coordinatesETRS89': [573705.0, 6767656.0, 0.0],
#    'direction1Municipality': 'Venäjä',
#    'direction1MunicipalityCode': 1006,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23534: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23534,
#    'tmsNumber': 534,
#    'name': 'vt6_Muukko',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Muukko',
#     'sv': 'Väg 6 Muukko',
#     'en': 'Road 6 Muukko'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 304,
#     'distanceFromRoadSectionStart': 3636,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi152844',
#    'country': None,
#    'startTime': '2011-12-29T22:00:00Z',
#    'repairMaintenanceTime': '2018-08-22T10:31:50Z',
#    'annualMaintenanceTime': '2017-08-23T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'ajantasa',
#    'coordinatesETRS89': [575728.0, 6774905.0, 0.0],
#    'direction1Municipality': 'Imatra',
#    'direction1MunicipalityCode': 153,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23547: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23547,
#    'tmsNumber': 547,
#    'name': 'vt13_Nuijamaa_MP5',
#    'collectionInterval': 0,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Nuijamaa',
#     'sv': 'Väg 13 Nuijamaa',
#     'en': 'Road 13 Nuijamaa'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 3443,
#     'carriagewayCode': 0,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'Livi154390',
#    'country': None,
#    'startTime': '2007-11-26T22:00:00Z',
#    'repairMaintenanceTime': '2017-08-02T07:41:19Z',
#    'annualMaintenanceTime': '2017-08-28T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'reaaliaika',
#    'coordinatesETRS89': [580760.0, 6761194.0, 0.0],
#    'direction1Municipality': None,
#    'direction1MunicipalityCode': 1002,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23556: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23556,
#    'tmsNumber': 556,
#    'name': 'vt6_Selkäharju',
#    'collectionInterval': 0,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Selkäharju',
#     'sv': 'Väg 6 Selkäharju',
#     'en': 'Road 6 Selkäharju'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 215,
#     'distanceFromRoadSectionStart': 1133,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi152735',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2017-08-22T21:00:00Z',
#    'state': None,
#    'purpose': 'reaaliaika',
#    'coordinatesETRS89': [557313.0, 6766412.0, 0.0],
#    'direction1Municipality': 'Lappeenranta',
#    'direction1MunicipalityCode': 405,
#    'direction2Municipality': 'Kouvola',
#    'direction2MunicipalityCode': 286,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23557: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23557,
#    'tmsNumber': 557,
#    'name': 'vt6_Lavola',
#    'collectionInterval': 0,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Lavola',
#     'sv': 'Väg 6 Lavola',
#     'en': 'Road 6 Lavola'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 216,
#     'distanceFromRoadSectionStart': 617,
#     'carriagewayCode': 2,
#     'roadMaintenanceClass': '2',
#     'contractAreaCode': 349,
#     'carriageway': 'DUAL_CARRIAGEWAY_SECOND_UPSTREAM'},
#    'liviId': 'Livi1005381',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2017-08-28T21:00:00Z',
#    'state': None,
#    'purpose': 'reaaliaika',
#    'coordinatesETRS89': [560828.0, 6767383.0, 0.0],
#    'direction1Municipality': 'Lappeenranta',
#    'direction1MunicipalityCode': 405,
#    'direction2Municipality': 'Kouvola',
#    'direction2MunicipalityCode': 286,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23558: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23558,
#    'tmsNumber': 558,
#    'name': 'vt6_Mattila',
#    'collectionInterval': 0,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Mattila',
#     'sv': 'Väg 6 Mattila',
#     'en': 'Road 6 Mattila'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 216,
#     'distanceFromRoadSectionStart': 2568,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractAreaCode': 349,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi152787',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': '2018-02-14T07:44:25Z',
#    'annualMaintenanceTime': '2017-08-23T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'reaaliaika',
#    'coordinatesETRS89': [562694.0, 6767933.0, 0.0],
#    'direction1Municipality': 'Lappeenranta',
#    'direction1MunicipalityCode': 405,
#    'direction2Municipality': 'Kouvola',
#    'direction2MunicipalityCode': 286,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23559: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23559,
#    'tmsNumber': 559,
#    'name': 'vt6_Myllymäki',
#    'collectionInterval': 0,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Myllymäki',
#     'sv': 'Väg 6 Myllymäki',
#     'en': 'Road 6 Myllymäki'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 301,
#     'distanceFromRoadSectionStart': 1248,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi152798',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': '2018-05-28T07:10:42Z',
#    'annualMaintenanceTime': '2017-08-28T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'reaaliaika',
#    'coordinatesETRS89': [564756.0, 6768160.0, 0.0],
#    'direction1Municipality': 'Imatra',
#    'direction1MunicipalityCode': 153,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23560: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23560,
#    'tmsNumber': 560,
#    'name': 'vt6_Karhuvuori',
#    'collectionInterval': 0,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Karhuvuori',
#     'sv': 'Väg 6 Karhuvuori',
#     'en': 'Road 6 Karhuvuori'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 302,
#     'distanceFromRoadSectionStart': 1989,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractAreaCode': 349,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi152813',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2017-10-12T21:00:00Z',
#    'state': None,
#    'purpose': 'reaaliaika',
#    'coordinatesETRS89': [567281.0, 6769122.0, 0.0],
#    'direction1Municipality': 'Imatra',
#    'direction1MunicipalityCode': 153,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23561: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23561,
#    'tmsNumber': 561,
#    'name': 'vt6_Hartikkala',
#    'collectionInterval': 0,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Hartikkala',
#     'sv': 'Väg 6 Hartikkala',
#     'en': 'Road 6 Hartikkala'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 302,
#     'distanceFromRoadSectionStart': 4277,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractAreaCode': 349,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi152816',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': '2017-11-21T06:41:47Z',
#    'annualMaintenanceTime': '2017-08-28T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'reaaliaika',
#    'coordinatesETRS89': [569211.0, 6770346.0, 0.0],
#    'direction1Municipality': 'Imatra',
#    'direction1MunicipalityCode': 153,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23562: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23562,
#    'tmsNumber': 562,
#    'name': 'vt6_Mälkiä',
#    'collectionInterval': 0,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Mälkiä',
#     'sv': 'Väg 6 Mälkiä',
#     'en': 'Road 6 Mälkiä'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 303,
#     'distanceFromRoadSectionStart': 1081,
#     'carriagewayCode': 2,
#     'roadMaintenanceClass': '2',
#     'contractAreaCode': 349,
#     'carriageway': 'DUAL_CARRIAGEWAY_SECOND_UPSTREAM'},
#    'liviId': 'Livi152835',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2017-08-29T21:00:00Z',
#    'state': None,
#    'purpose': 'reaaliaika',
#    'coordinatesETRS89': [570681.0, 6771491.0, 0.0],
#    'direction1Municipality': 'Imatra',
#    'direction1MunicipalityCode': 153,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23563: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23563,
#    'tmsNumber': 563,
#    'name': 'vt6_Joutseno',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Joutseno',
#     'sv': 'Väg 6 Joutseno',
#     'en': 'Road 6 Joutseno'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 305,
#     'distanceFromRoadSectionStart': 2522,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractAreaCode': 350,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi152846',
#    'country': None,
#    'startTime': '2012-08-05T21:00:00Z',
#    'repairMaintenanceTime': '2016-11-15T10:06:42Z',
#    'annualMaintenanceTime': '2017-08-28T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'ajantasa',
#    'coordinatesETRS89': [580557.0, 6777116.0, 0.0],
#    'direction1Municipality': 'Imatra',
#    'direction1MunicipalityCode': 153,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23564: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23564,
#    'tmsNumber': 564,
#    'name': 'vt6_Vesivalo',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Vesivalo',
#     'sv': 'Väg 6 Vesivalo',
#     'en': 'Road 6 Vesivalo'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 307,
#     'distanceFromRoadSectionStart': 3939,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractAreaCode': 350,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi153194',
#    'country': None,
#    'startTime': '2012-08-05T21:00:00Z',
#    'repairMaintenanceTime': '2018-07-06T04:22:06Z',
#    'annualMaintenanceTime': '2017-08-28T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'ajantasa',
#    'coordinatesETRS89': [590335.0, 6782427.0, 0.0],
#    'direction1Municipality': 'Imatra',
#    'direction1MunicipalityCode': 153,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23582: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23582,
#    'tmsNumber': 582,
#    'name': 'vt13_Nuijamaa',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Nuijamaa',
#     'sv': 'Väg 13 Nuijamaa',
#     'en': 'Road 13 Nuijamaa'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 5078,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '3',
#     'contractAreaCode': 343,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi154358',
#    'country': None,
#    'startTime': '2006-11-30T22:00:00Z',
#    'repairMaintenanceTime': '2018-10-01T12:23:45Z',
#    'annualMaintenanceTime': '2017-10-12T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'ajantasa',
#    'coordinatesETRS89': [581416.0, 6759770.0, 0.0],
#    'direction1Municipality': 'Venäjä',
#    'direction1MunicipalityCode': 1006,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23593: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23593,
#    'tmsNumber': 593,
#    'name': 'st387_Ylämaa',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 387 Ylämaa',
#     'sv': 'Väg 387 Ylämaa',
#     'en': 'Road 387 Ylämaa'},
#    'roadAddress': {'roadNumber': 387,
#     'roadSection': 7,
#     'distanceFromRoadSectionStart': 3343,
#     'carriagewayCode': 0,
#     'roadMaintenanceClass': '4',
#     'contractArea': 'Kotka 13 - 20',
#     'contractAreaCode': 386,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'Livi155471',
#    'country': None,
#    'startTime': '2005-03-14T22:00:00Z',
#    'repairMaintenanceTime': '2019-03-15T13:09:05Z',
#    'annualMaintenanceTime': '2017-08-22T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'ajantasa',
#    'coordinatesETRS89': [553391.0, 6737014.0, 0.0],
#    'direction1Municipality': 'Vaalimaa',
#    'direction1MunicipalityCode': 1000,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}},
#  23597: {'Timestamp': '2019-03-21T12:05:09Z',
#   'roadStationId': {'roadStationId': 23597,
#    'tmsNumber': 597,
#    'name': 'vt13_Nuijamaa_rask',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Nuijamaa, raskaat',
#     'sv': 'Väg 13 Nuijamaa',
#     'en': 'Road 13 Nuijamaa'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 5705,
#     'carriagewayCode': 2,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_SECOND_UPSTREAM'},
#    'liviId': 'Livi1010523',
#    'country': None,
#    'startTime': '2006-12-07T22:00:00Z',
#    'repairMaintenanceTime': '2018-10-24T06:07:14Z',
#    'annualMaintenanceTime': '2017-08-29T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'ajantasa',
#    'coordinatesETRS89': [581788.0, 6759298.0, 0.0],
#    'direction1Municipality': 'Venäjä',
#    'direction1MunicipalityCode': 1006,
#    'direction2Municipality': 'Lappeenranta',
#    'direction2MunicipalityCode': 405,
#    'calculatorDeviceType': None,
#    'stationSensors': [5054,
#     5055,
#     5056,
#     5057,
#     5058,
#     5061,
#     5064,
#     5067,
#     5068,
#     5071,
#     5116,
#     5119,
#     5122,
#     5125,
#     5158,
#     5161,
#     5164,
#     5168],
#    'tmsStationType': 'DSL_4'}}}

# %%
with open('static_tms_stations.json', 'w') as fp:
    json.dump(vault, fp)

# %%
r=requests.get(url='https://tie.digitraffic.fi/api/v1/data/free-flow-speeds?lastUpdated=false')

# %%
print(r.json())
# Out:
# {'dataUpdatedTime': '2019-02-26T09:33:37Z', 'linkFreeFlowSpeeds': [], 'tmsFreeFlowSpeeds': [{'freeFlowSpeed1': 83.0, 'freeFlowSpeed2': 83.0, 'id': 23165, 'tmsNumber': 165}, {'freeFlowSpeed1': 95.0, 'freeFlowSpeed2': 95.0, 'id': 23175, 'tmsNumber': 175}, {'freeFlowSpeed1': 95.0, 'freeFlowSpeed2': 95.0, 'id': 23176, 'tmsNumber': 176}, {'freeFlowSpeed1': 70.0, 'freeFlowSpeed2': 70.0, 'id': 23605, 'tmsNumber': 605}, {'freeFlowSpeed1': 86.0, 'freeFlowSpeed2': 86.0, 'id': 23805, 'tmsNumber': 805}, {'freeFlowSpeed1': 83.0, 'freeFlowSpeed2': 83.0, 'id': 23162, 'tmsNumber': 162}, {'freeFlowSpeed1': 83.0, 'freeFlowSpeed2': 83.0, 'id': 23163, 'tmsNumber': 163}, {'freeFlowSpeed1': 90.0, 'freeFlowSpeed2': 90.0, 'id': 23179, 'tmsNumber': 179}, {'freeFlowSpeed1': 95.0, 'freeFlowSpeed2': 105.0, 'id': 23185, 'tmsNumber': 185}, {'freeFlowSpeed1': 95.0, 'freeFlowSpeed2': 105.0, 'id': 23187, 'tmsNumber': 187}, {'freeFlowSpeed1': 95.0, 'freeFlowSpeed2': 105.0, 'id': 23188, 'tmsNumber': 188}, {'freeFlowSpeed1': 77.0, 'freeFlowSpeed2': 77.0, 'id': 23205, 'tmsNumber': 205}, {'freeFlowSpeed1': 77.0, 'freeFlowSpeed2': 77.0, 'id': 23208, 'tmsNumber': 208}, {'freeFlowSpeed1': 77.0, 'freeFlowSpeed2': 77.0, 'id': 23209, 'tmsNumber': 209}, {'freeFlowSpeed1': 77.0, 'freeFlowSpeed2': 77.0, 'id': 23229, 'tmsNumber': 229}, {'freeFlowSpeed1': 61.0, 'freeFlowSpeed2': 61.0, 'id': 23230, 'tmsNumber': 230}, {'freeFlowSpeed1': 76.0, 'freeFlowSpeed2': 76.0, 'id': 23231, 'tmsNumber': 231}, {'freeFlowSpeed1': 88.0, 'freeFlowSpeed2': 88.0, 'id': 23240, 'tmsNumber': 240}, {'freeFlowSpeed1': 88.0, 'freeFlowSpeed2': 88.0, 'id': 23242, 'tmsNumber': 242}, {'freeFlowSpeed1': 75.0, 'freeFlowSpeed2': 75.0, 'id': 23127, 'tmsNumber': 127}, {'freeFlowSpeed1': 92.0, 'freeFlowSpeed2': 92.0, 'id': 23131, 'tmsNumber': 131}, {'freeFlowSpeed1': 80.0, 'freeFlowSpeed2': 80.0, 'id': 23133, 'tmsNumber': 133}, {'freeFlowSpeed1': 80.0, 'freeFlowSpeed2': 80.0, 'id': 23134, 'tmsNumber': 134}, {'freeFlowSpeed1': 65.0, 'freeFlowSpeed2': 65.0, 'id': 23135, 'tmsNumber': 135}, {'freeFlowSpeed1': 77.0, 'freeFlowSpeed2': 77.0, 'id': 23136, 'tmsNumber': 136}, {'freeFlowSpeed1': 95.0, 'freeFlowSpeed2': 95.0, 'id': 23137, 'tmsNumber': 137}, {'freeFlowSpeed1': 95.0, 'freeFlowSpeed2': 95.0, 'id': 23139, 'tmsNumber': 139}, {'freeFlowSpeed1': 90.0, 'freeFlowSpeed2': 90.0, 'id': 23140, 'tmsNumber': 140}, {'freeFlowSpeed1': 95.0, 'freeFlowSpeed2': 95.0, 'id': 23141, 'tmsNumber': 141}, {'freeFlowSpeed1': 98.0, 'freeFlowSpeed2': 95.0, 'id': 23144, 'tmsNumber': 144}, {'freeFlowSpeed1': 80.0, 'freeFlowSpeed2': 80.0, 'id': 23150, 'tmsNumber': 150}, {'freeFlowSpeed1': 93.0, 'freeFlowSpeed2': 93.0, 'id': 23579, 'tmsNumber': 579}, {'freeFlowSpeed1': 93.0, 'freeFlowSpeed2': 93.0, 'id': 23580, 'tmsNumber': 580}, {'freeFlowSpeed1': 70.0, 'freeFlowSpeed2': 70.0, 'id': 23593, 'tmsNumber': 593}, {'freeFlowSpeed1': 55.0, 'freeFlowSpeed2': 55.0, 'id': 23438, 'tmsNumber': 438}, {'freeFlowSpeed1': 53.0, 'freeFlowSpeed2': 53.0, 'id': 23439, 'tmsNumber': 439}, {'freeFlowSpeed1': 77.0, 'freeFlowSpeed2': 77.0, 'id': 23445, 'tmsNumber': 445}, {'freeFlowSpeed1': 70.0, 'freeFlowSpeed2': 70.0, 'id': 23455, 'tmsNumber': 455}, {'freeFlowSpeed1': 55.0, 'freeFlowSpeed2': 55.0, 'id': 23457, 'tmsNumber': 457}, {'freeFlowSpeed1': 70.0, 'freeFlowSpeed2': 70.0, 'id': 23458, 'tmsNumber': 458}, {'freeFlowSpeed1': 88.0, 'freeFlowSpeed2': 88.0, 'id': 23461, 'tmsNumber': 461}, {'freeFlowSpeed1': 80.0, 'freeFlowSpeed2': 80.0, 'id': 23576, 'tmsNumber': 576}, {'freeFlowSpeed1': 88.0, 'freeFlowSpeed2': 88.0, 'id': 23577, 'tmsNumber': 577}, {'freeFlowSpeed1': 88.0, 'freeFlowSpeed2': 88.0, 'id': 23832, 'tmsNumber': 832}, {'freeFlowSpeed1': 88.0, 'freeFlowSpeed2': 88.0, 'id': 23834, 'tmsNumber': 834}, {'freeFlowSpeed1': 88.0, 'freeFlowSpeed2': 88.0, 'id': 23836, 'tmsNumber': 836}, {'freeFlowSpeed1': 90.0, 'freeFlowSpeed2': 90.0, 'id': 23305, 'tmsNumber': 305}, {'freeFlowSpeed1': 75.0, 'freeFlowSpeed2': 75.0, 'id': 23403, 'tmsNumber': 403}, {'freeFlowSpeed1' ...

# %%
freeflowspeeds = r.json()
counter = 0
freeflowspeedsdata = {}

for i in freeflowspeeds['tmsFreeFlowSpeeds']:
    if i['tmsNumber'] == 306 or i['tmsNumber'] == 533 or i['tmsNumber'] == 534 or i['tmsNumber'] == 547 or i['tmsNumber'] == 556 or i['tmsNumber'] == 557 or i['tmsNumber'] == 558 or i['tmsNumber'] == 559 or i['tmsNumber'] == 560 or i['tmsNumber'] == 561 or i['tmsNumber'] == 562 or i['tmsNumber'] == 563 or i['tmsNumber'] == 564 or i['tmsNumber'] == 582 or i['tmsNumber'] == 593 or i['tmsNumber'] == 597:
        freeflowspeedsdata[i['id']] = {'timestamp':freeflowspeeds['dataUpdatedTime'],
                                    'freeFlowSpeed1': i['freeFlowSpeed1'],
                                    'freeFlowSpeed2': i['freeFlowSpeed2'],
                                    'tmsNumber':i['tmsNumber']
                                      }

# %%
freeflowspeedsdata
# Out:
# {23533: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 80.0,
#   'freeFlowSpeed2': 80.0,
#   'tmsNumber': 533},
#  23534: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 83.0,
#   'freeFlowSpeed2': 83.0,
#   'tmsNumber': 534},
#  23306: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 25.0,
#   'freeFlowSpeed2': 25.0,
#   'tmsNumber': 306},
#  23593: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 70.0,
#   'freeFlowSpeed2': 70.0,
#   'tmsNumber': 593},
#  23557: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 90.0,
#   'freeFlowSpeed2': 90.0,
#   'tmsNumber': 557},
#  23558: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 90.0,
#   'freeFlowSpeed2': 90.0,
#   'tmsNumber': 558},
#  23559: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 90.0,
#   'freeFlowSpeed2': 90.0,
#   'tmsNumber': 559},
#  23560: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 90.0,
#   'freeFlowSpeed2': 90.0,
#   'tmsNumber': 560},
#  23597: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 25.0,
#   'freeFlowSpeed2': 25.0,
#   'tmsNumber': 597},
#  23582: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 40.0,
#   'freeFlowSpeed2': 40.0,
#   'tmsNumber': 582},
#  23562: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 90.0,
#   'freeFlowSpeed2': 90.0,
#   'tmsNumber': 562},
#  23563: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 90.0,
#   'freeFlowSpeed2': 90.0,
#   'tmsNumber': 563},
#  23564: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 90.0,
#   'freeFlowSpeed2': 90.0,
#   'tmsNumber': 564},
#  23547: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 25.0,
#   'freeFlowSpeed2': 25.0,
#   'tmsNumber': 547},
#  23556: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 90.0,
#   'freeFlowSpeed2': 90.0,
#   'tmsNumber': 556},
#  23561: {'timestamp': '2019-02-26T09:33:37Z',
#   'freeFlowSpeed1': 90.0,
#   'freeFlowSpeed2': 90.0,
#   'tmsNumber': 561}}

# %%
with open('free_flow_speeds.json', 'w') as fp:
    json.dump(freeflowspeedsdata, fp)

# %%
r=requests.get(url='https://tie.digitraffic.fi/api/v1/metadata/camera-stations?lastUpdated=false')

# %%
print(r.json())
# Out:
# {'dataUpdatedTime': '2019-03-21T15:16:15Z', 'weatherData': [{'id': '00009_303_000_0', 'roadConditions': [{'time': '2019-03-21T15:05:00Z', 'type': 'OBSERVATION', 'forecastName': '0h', 'daylight': True, 'roadTemperature': '+4', 'temperature': '+5.0', 'windSpeed': 2.8, 'windDirection': 212, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd400', 'reliability': 'SUCCESSFUL'}, {'time': '2019-03-21T16:00:00Z', 'type': 'FORECAST', 'forecastName': '2h', 'daylight': True, 'roadTemperature': '4', 'temperature': '5', 'windSpeed': 3.0, 'windDirection': 212, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd400', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'MOIST'}}, {'time': '2019-03-21T18:00:00Z', 'type': 'FORECAST', 'forecastName': '4h', 'daylight': False, 'roadTemperature': '+2', 'temperature': '+3', 'windSpeed': 4.0, 'windDirection': 259, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'n000', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'MOIST'}}, {'time': '2019-03-21T20:00:00Z', 'type': 'FORECAST', 'forecastName': '6h', 'daylight': False, 'roadTemperature': '+0', 'temperature': '+1', 'windSpeed': 4.0, 'windDirection': 286, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'n000', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'MOIST'}}, {'time': '2019-03-22T02:00:00Z', 'type': 'FORECAST', 'forecastName': '12h', 'daylight': False, 'roadTemperature': '-3', 'temperature': '-2', 'windSpeed': 6.0, 'windDirection': 310, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'n100', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'DRY'}}]}, {'id': '00028_038_000_0', 'roadConditions': [{'time': '2019-03-21T15:01:00Z', 'type': 'OBSERVATION', 'forecastName': '0h', 'daylight': True, 'roadTemperature': '+2.2', 'temperature': '+3.2', 'windSpeed': 1.4, 'windDirection': 185, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd400', 'reliability': 'SUCCESSFUL'}, {'time': '2019-03-21T16:00:00Z', 'type': 'FORECAST', 'forecastName': '2h', 'daylight': True, 'roadTemperature': '2', 'temperature': '3', 'windSpeed': 1.0, 'windDirection': 185, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd400', 'reliability': 'NO_DATA_FROM_ROADSTATION'}, {'time': '2019-03-21T18:00:00Z', 'type': 'FORECAST', 'forecastName': '4h', 'daylight': False, 'roadTemperature': '+1', 'temperature': '+2', 'windSpeed': 4.0, 'windDirection': 258, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'n100', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'MOIST'}}, {'time': '2019-03-21T20:00:00Z', 'type': 'FORECAST', 'forecastName': '6h', 'daylight': False, 'roadTemperature': '0', 'temperature': '+0', 'windSpeed': 5.0, 'windDirection': 282, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'n200', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'DRY'}}, {'time': '2019-03-22T02:00:00Z', 'type': 'FORECAST', 'forecastName': '12h', 'daylight': False, 'roadTemperature': '-2', 'temperature': '-1', 'windSpeed': 8.0, 'windDirection': 314, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'n400', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'DRY'}}]}, {'id': '00001_019_000_0', 'roadConditions': [{'time': '2019-03-21T15:07:00Z', 'type': 'OBSERVATION', 'forecastName': '0h', 'daylight': True, 'roadTemperature': '+6.1', 'temperature': '+3.9', 'windSpeed': 2.8, 'windDirection': 244, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd300', 'reliability': 'SUCCESSFUL'}, {'time': '2019-03-21T16:00:00Z', 'type': 'FORECAST', 'forecastName': '2h', 'daylight': True, 'roadTemperature': '6', 'temperature': '4', 'windSpeed': 3.0, 'windDirection': 244, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherS ...

# %%
cameras = r.json()
counter = 0
camera_stations = {}

for i in cameras['features']:
    if i['properties']['municipalityCode'] == '405':
        camera_stations[i['id']] = {'timestamp':cameras['dataUpdatedTime'],
                                    'roadStationId':i["properties"]
                                      }

# %%
camera_stations
# Out:
# {'3510': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3510,
#    'id': 'C03510',
#    'name': 'vt13_Nuijamaa_raja',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Nuijamaa',
#     'sv': 'Väg 13 Nuijamaa',
#     'en': 'Road 13 Nuijamaa'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 6112,
#     'carriagewayCode': 0,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'KAMM212',
#    'country': None,
#    'startTime': '2009-10-29T22:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2018-08-28T21:00:00Z',
#    'state': None,
#    'purpose': 'keli',
#    'coordinatesETRS89': [582041.0, 6758986.0, 0.0],
#    'presets': [{'presetId': 'C0351002',
#      'cameraId': 'C03510',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0351002.jpg',
#      'direction': 'DECREASING_DIRECTION'}],
#    'nearestWeatherStationId': 3012}},
#  '3529': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3529,
#    'id': 'C03529',
#    'name': 'vt6_Muukko',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Lappeenranta, Muukko',
#     'sv': 'Väg 6 Villmanstrand, Muukko',
#     'en': 'Road 6 Lappeenranta, Muukko'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 304,
#     'distanceFromRoadSectionStart': 1868,
#     'carriagewayCode': 2,
#     'roadMaintenanceClass': '2',
#     'contractAreaCode': 349,
#     'carriageway': 'DUAL_CARRIAGEWAY_SECOND_UPSTREAM'},
#    'liviId': 'Livi1089175',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': '2015-10-22T12:25:29Z',
#    'annualMaintenanceTime': '2018-08-22T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [574095.0, 6774225.0, 0.0],
#    'presets': [{'presetId': 'C0352901',
#      'cameraId': 'C03529',
#      'presentationName': 'Imatralle',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0352901.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0352902',
#      'cameraId': 'C03529',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0352902.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0352909',
#      'cameraId': 'C03529',
#      'presentationName': 'Tienpinta',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0352909.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 5008}},
#  '3536': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3536,
#    'id': 'C03536',
#    'name': 'vt13_Nuijamaa_rajalle_5km',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Rajalle 5km',
#     'sv': 'Väg 13 5.0km till gränsen',
#     'en': 'Road 13 5.0km to border'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 1500,
#     'carriagewayCode': 0,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'Livi1089415',
#    'country': None,
#    'startTime': '2006-12-31T22:00:00Z',
#    'repairMaintenanceTime': '2015-12-01T06:12:59Z',
#    'annualMaintenanceTime': '2018-08-28T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [578867.0, 6762756.0, 0.0],
#    'presets': [{'presetId': 'C0353601',
#      'cameraId': 'C03536',
#      'presentationName': 'Nuijamaalle',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0353601.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0353602',
#      'cameraId': 'C03536',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0353602.jpg',
#      'direction': 'DECREASING_DIRECTION'}],
#    'nearestWeatherStationId': 3012}},
#  '3542': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3542,
#    'id': 'C03542',
#    'name': 'vt13_Nuijamaa_rajalle_4_5km',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Rajalle 4.5km',
#     'sv': 'Väg 13 4.5km till gränsen',
#     'en': 'Road 13 4.5km to border'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 1000,
#     'carriagewayCode': 0,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'Livi1089414',
#    'country': None,
#    'startTime': '2006-12-31T22:00:00Z',
#    'repairMaintenanceTime': '2018-11-22T14:07:17Z',
#    'annualMaintenanceTime': '2018-08-28T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [579431.0, 6762374.0, 0.0],
#    'presets': [{'presetId': 'C0354202',
#      'cameraId': 'C03542',
#      'presentationName': 'Länteen',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0354202.jpg',
#      'direction': 'DECREASING_DIRECTION'}],
#    'nearestWeatherStationId': 3012}},
#  '3543': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3543,
#    'id': 'C03543',
#    'name': 'vt13_Nuijamaa_rajalle_4km',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Rajalle 4.0km',
#     'sv': 'Väg 13 4.0km till gränsen',
#     'en': 'Road 13 4.0km to border'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 1550,
#     'carriagewayCode': 0,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'Livi1089413',
#    'country': None,
#    'startTime': '2006-12-31T22:00:00Z',
#    'repairMaintenanceTime': '2018-10-11T10:44:49Z',
#    'annualMaintenanceTime': '2018-08-28T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [579969.0, 6761911.0, 0.0],
#    'presets': [{'presetId': 'C0354301',
#      'cameraId': 'C03543',
#      'presentationName': 'Rajalle',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0354301.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0354302',
#      'cameraId': 'C03543',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0354302.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0354309',
#      'cameraId': 'C03543',
#      'presentationName': 'Tienpinta',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0354309.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 3012}},
#  '3544': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3544,
#    'id': 'C03544',
#    'name': 'vt13_Nuijamaa_rajalle_2_5km',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Rajalle 2.5km',
#     'sv': 'Väg 13 2.5km till gränsen',
#     'en': 'Road 13 2.5km to border'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 3800,
#     'carriagewayCode': 0,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'Livi1089412',
#    'country': None,
#    'startTime': '2006-12-31T22:00:00Z',
#    'repairMaintenanceTime': '2017-07-26T09:11:00Z',
#    'annualMaintenanceTime': '2018-08-28T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [580989.0, 6760907.0, 0.0],
#    'presets': [{'presetId': 'C0354401',
#      'cameraId': 'C03544',
#      'presentationName': 'Itään',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0354401.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0354402',
#      'cameraId': 'C03544',
#      'presentationName': 'Länteen',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0354402.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0354409',
#      'cameraId': 'C03544',
#      'presentationName': 'tienpinta',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0354409.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 3012}},
#  '3545': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3545,
#    'id': 'C03545',
#    'name': 'vt13_Nuijamaa_puomi',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Raja, puomi',
#     'sv': 'Väg 13 Gränsen, bommen',
#     'en': 'Road 13 Border, barrier'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 4950,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi1089411',
#    'country': None,
#    'startTime': '2006-12-31T22:00:00Z',
#    'repairMaintenanceTime': '2016-05-13T12:38:32Z',
#    'annualMaintenanceTime': '2018-08-28T21:00:00Z',
#    'state': 'REPAIR_MAINTENANCE_DONE',
#    'purpose': 'keli',
#    'coordinatesETRS89': [581401.0, 6759904.0, 0.0],
#    'presets': [{'presetId': 'C0354500',
#      'cameraId': 'C03545',
#      'presentationName': 'Rajapuomi',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '0',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0354500.jpg',
#      'direction': 'UNKNOWN'}],
#    'nearestWeatherStationId': 3012}},
#  '3546': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3546,
#    'id': 'C03546',
#    'name': 'vt13_Nuijamaa_parkkialue1',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Raja, parkki 1',
#     'sv': 'Väg 13 Gränsen, parkeringspl',
#     'en': 'Road 13 Border, truckpark 1'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 5500,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi1089410',
#    'country': None,
#    'startTime': '2006-12-31T22:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2018-08-28T21:00:00Z',
#    'state': None,
#    'purpose': 'keli',
#    'coordinatesETRS89': [581611.0, 6759468.0, 0.0],
#    'presets': [{'presetId': 'C0354600',
#      'cameraId': 'C03546',
#      'presentationName': 'Parkkialue',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '0',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0354600.jpg',
#      'direction': 'UNKNOWN'}],
#    'nearestWeatherStationId': 3012}},
#  '3547': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3547,
#    'id': 'C03547',
#    'name': 'vt13_Nuijamaa_parkkialue2',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Raja, parkki 2',
#     'sv': 'Väg 13 Gränsen, parkeringspl',
#     'en': 'Road 13 Border, truckpark 2'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 5600,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi1089409',
#    'country': None,
#    'startTime': '2006-12-31T22:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2018-08-28T21:00:00Z',
#    'state': None,
#    'purpose': 'keli',
#    'coordinatesETRS89': [581692.0, 6759378.0, 0.0],
#    'presets': [{'presetId': 'C0354700',
#      'cameraId': 'C03547',
#      'presentationName': 'Parkkialue',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '0',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0354700.jpg',
#      'direction': 'UNKNOWN'}],
#    'nearestWeatherStationId': 3012}},
#  '3558': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3558,
#    'id': 'C03558',
#    'name': 'vt6_Saimaan_kanava',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Saimaan kanava',
#     'sv': 'Väg 6 Saima kanal',
#     'en': 'Road 6 Saimaa channel'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 303,
#     'distanceFromRoadSectionStart': 1045,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi1089173',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': '2018-06-07T06:21:58Z',
#    'annualMaintenanceTime': '2018-08-22T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [570560.0, 6771405.0, 0.0],
#    'presets': [{'presetId': 'C0355801',
#      'cameraId': 'C03558',
#      'presentationName': 'Imatralle',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0355801.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0355802',
#      'cameraId': 'C03558',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0355802.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0355809',
#      'cameraId': 'C03558',
#      'presentationName': 'Tienpinta',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0355809.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 5008}},
#  '3565': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3565,
#    'id': 'C03565',
#    'name': 'vt13_Lokkaan_suora',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Lokkaan suora',
#     'sv': 'Väg 13 Lokkaa rakan',
#     'en': 'Road 13 Lokkaa straight'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 240,
#     'distanceFromRoadSectionStart': 2729,
#     'carriagewayCode': 0,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'Livi1089408',
#    'country': None,
#    'startTime': '2008-09-30T21:00:00Z',
#    'repairMaintenanceTime': '2019-01-15T05:46:00Z',
#    'annualMaintenanceTime': '2018-08-28T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [575441.0, 6766076.0, 0.0],
#    'presets': [{'presetId': 'C0356501',
#      'cameraId': 'C03565',
#      'presentationName': 'Rajalle',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0356501.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0356502',
#      'cameraId': 'C03565',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0356502.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0356509',
#      'cameraId': 'C03565',
#      'presentationName': 'Tienpinta',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0356509.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 3012}},
#  '3566': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3566,
#    'id': 'C03566',
#    'name': 'vt6_Lappeenranta',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 600,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Lappeenranta',
#     'sv': 'Väg 6 Villmanstrand',
#     'en': 'Road 6 Lappeenranta'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 301,
#     'distanceFromRoadSectionStart': 680,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi1089171',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': '2017-01-04T13:21:18Z',
#    'annualMaintenanceTime': '2018-08-22T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [564217.0, 6767993.0, 0.0],
#    'presets': [{'presetId': 'C0356601',
#      'cameraId': 'C03566',
#      'presentationName': 'Imatralle',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0356601.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0356602',
#      'cameraId': 'C03566',
#      'presentationName': 'Kouvolaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0356602.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0356609',
#      'cameraId': 'C03566',
#      'presentationName': 'tienpinta',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0356609.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 3036}},
#  '3568': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3568,
#    'id': 'C03568',
#    'name': 'vt6_Muukon_suora',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Muukon suora',
#     'sv': 'Tie 6 Muukko rakan',
#     'en': 'Road 6 Muukko straight'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 304,
#     'distanceFromRoadSectionStart': 3678,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi1089170',
#    'country': None,
#    'startTime': '2008-09-30T21:00:00Z',
#    'repairMaintenanceTime': '2019-01-04T08:21:14Z',
#    'annualMaintenanceTime': '2018-08-27T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [575763.0, 6774920.0, 0.0],
#    'presets': [{'presetId': 'C0356801',
#      'cameraId': 'C03568',
#      'presentationName': 'Imatralle',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0356801.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0356802',
#      'cameraId': 'C03568',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0356802.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0356809',
#      'cameraId': 'C03568',
#      'presentationName': 'Tienpinta',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0356809.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 5008}},
#  '3570': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3570,
#    'id': 'C03570',
#    'name': 'vt13_Karhusjärvi',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Karhusjärvi',
#     'sv': 'Väg 13 Karhusjärvi',
#     'en': 'Road 13 Karhusjärvi'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 239,
#     'distanceFromRoadSectionStart': 4759,
#     'carriagewayCode': 0,
#     'roadMaintenanceClass': '3',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'Livi1089407',
#    'country': None,
#    'startTime': '2008-09-30T21:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2018-08-28T21:00:00Z',
#    'state': None,
#    'purpose': 'keli',
#    'coordinatesETRS89': [573435.0, 6768102.0, 0.0],
#    'presets': [{'presetId': 'C0357001',
#      'cameraId': 'C03570',
#      'presentationName': 'Nuijamaalle',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357001.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0357002',
#      'cameraId': 'C03570',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357002.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0357009',
#      'cameraId': 'C03570',
#      'presentationName': 'Tienpinta',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357009.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 3012}},
#  '3571': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3571,
#    'id': 'C03571',
#    'name': 'vt6_Lappeenranta_Selkäharju',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Lappeenranta, Selkäharju',
#     'sv': 'Väg 6 Villmanstrand, Selkäharju',
#     'en': 'Road 6 Lappeenranta, Selkäharju'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 215,
#     'distanceFromRoadSectionStart': 65,
#     'carriagewayCode': 2,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_SECOND_UPSTREAM'},
#    'liviId': 'Livi1089169',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2018-08-27T21:00:00Z',
#    'state': None,
#    'purpose': 'keli',
#    'coordinatesETRS89': [556262.0, 6766167.0, 0.0],
#    'presets': [{'presetId': 'C0357101',
#      'cameraId': 'C03571',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357101.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0357102',
#      'cameraId': 'C03571',
#      'presentationName': 'Kouvolaan',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357102.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0357109',
#      'cameraId': 'C03571',
#      'presentationName': 'Tienpinta',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357109.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 3036}},
#  '3572': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3572,
#    'id': 'C03572',
#    'name': 'vt6_Lappeenranta_Lavola',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Lappeenranta, Lavola',
#     'sv': 'Väg 6 Villmanstrand, Lavola',
#     'en': 'Road 6 Lappeenranta, Lavola'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 216,
#     'distanceFromRoadSectionStart': 12,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi1089168',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': '2016-05-06T13:10:01Z',
#    'annualMaintenanceTime': '2018-08-22T21:00:00Z',
#    'state': 'OK_FAULT_DOUBT_CANCELLED',
#    'purpose': 'keli',
#    'coordinatesETRS89': [560249.0, 6767195.0, 0.0],
#    'presets': [{'presetId': 'C0357201',
#      'cameraId': 'C03572',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357201.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0357202',
#      'cameraId': 'C03572',
#      'presentationName': 'Kouvolaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357202.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0357209',
#      'cameraId': 'C03572',
#      'presentationName': 'Tienpinta',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357209.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 3036}},
#  '3573': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3573,
#    'id': 'C03573',
#    'name': 'vt6_Viipurintie',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Lappeenranta, Viipurintie',
#     'sv': 'Väg 6 Villmanstrand, Viipurintie',
#     'en': 'Road 6 Lappeenranta, Viipurintie'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 301,
#     'distanceFromRoadSectionStart': 1974,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi1089167',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': '2018-09-07T11:55:23Z',
#    'annualMaintenanceTime': '2018-08-27T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [565436.0, 6768374.0, 0.0],
#    'presets': [{'presetId': 'C0357301',
#      'cameraId': 'C03573',
#      'presentationName': 'Imatralle',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357301.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0357302',
#      'cameraId': 'C03573',
#      'presentationName': 'Kouvolaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357302.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0357309',
#      'cameraId': 'C03573',
#      'presentationName': 'Tienpinta',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357309.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 5008}},
#  '3574': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3574,
#    'id': 'C03574',
#    'name': 'vt6_Lappeenranta_Nuijamaantie',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Lappeenranta, Nuijamaantie',
#     'sv': 'Väg 6 Villmanstrand, Nuijamaantie',
#     'en': 'Road 6 Lappeenranta, Nuijamaantie'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 302,
#     'distanceFromRoadSectionStart': 5064,
#     'carriagewayCode': 2,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Lappeenranta 16-21',
#     'contractAreaCode': 388,
#     'carriageway': 'DUAL_CARRIAGEWAY_SECOND_UPSTREAM'},
#    'liviId': 'Livi1089166',
#    'country': None,
#    'startTime': '2010-12-29T22:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2018-08-22T21:00:00Z',
#    'state': None,
#    'purpose': 'keli',
#    'coordinatesETRS89': [569788.0, 6770864.0, 0.0],
#    'presets': [{'presetId': 'C0357401',
#      'cameraId': 'C03574',
#      'presentationName': 'Imatralle',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357401.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0357402',
#      'cameraId': 'C03574',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357402.jpg',
#      'direction': 'DECREASING_DIRECTION'}],
#    'nearestWeatherStationId': 5008}},
#  '3577': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3577,
#    'id': 'C03577',
#    'name': 'vt6_Joutseno',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Lappeenranta, Joutseno',
#     'sv': 'Väg 6 Villmanstrand, jotseno',
#     'en': 'Road 6 Lappeenranta, Joutseno'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 305,
#     'distanceFromRoadSectionStart': 1733,
#     'carriagewayCode': 1,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Imatra 16-21',
#     'contractAreaCode': 387,
#     'carriageway': 'DUAL_CARRIAGEWAY_FIRST_MEASURING_DIRECTION'},
#    'liviId': 'Livi1089165',
#    'country': None,
#    'startTime': '2012-08-05T21:00:00Z',
#    'repairMaintenanceTime': '2017-08-02T07:41:02Z',
#    'annualMaintenanceTime': '2018-08-27T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [579908.0, 6776703.0, 0.0],
#    'presets': [{'presetId': 'C0357701',
#      'cameraId': 'C03577',
#      'presentationName': 'Imatralle',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357701.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0357702',
#      'cameraId': 'C03577',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357702.jpg',
#      'direction': 'DECREASING_DIRECTION'}],
#    'nearestWeatherStationId': 5008}},
#  '3578': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3578,
#    'id': 'C03578',
#    'name': 'vt6_Vesivalo',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 6 Imatra, Vesivalo',
#     'sv': 'Väg 6 Imatra, Vesivalo',
#     'en': 'Road 6 Imatra, Vesivalo'},
#    'roadAddress': {'roadNumber': 6,
#     'roadSection': 308,
#     'distanceFromRoadSectionStart': 5,
#     'carriagewayCode': 2,
#     'roadMaintenanceClass': '2',
#     'contractArea': 'Imatra 16-21',
#     'contractAreaCode': 387,
#     'carriageway': 'DUAL_CARRIAGEWAY_SECOND_UPSTREAM'},
#    'liviId': 'Livi1089164',
#    'country': None,
#    'startTime': '2012-08-05T21:00:00Z',
#    'repairMaintenanceTime': None,
#    'annualMaintenanceTime': '2018-08-08T21:00:00Z',
#    'state': None,
#    'purpose': 'keli',
#    'coordinatesETRS89': [591463.0, 6783232.0, 0.0],
#    'presets': [{'presetId': 'C0357801',
#      'cameraId': 'C03578',
#      'presentationName': 'Imatralle',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357801.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0357802',
#      'cameraId': 'C03578',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0357802.jpg',
#      'direction': 'DECREASING_DIRECTION'}],
#    'nearestWeatherStationId': 5004}},
#  '3580': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3580,
#    'id': 'C03580',
#    'name': 'st387_Lappeenranta_Ylämaa',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 720,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 387 Lappeenranta, Ylämaa',
#     'sv': 'Väg 387 Villmarstrand, Ylämaa',
#     'en': 'Road 387 Lappeenranta, Ylämaa'},
#    'roadAddress': {'roadNumber': 387,
#     'roadSection': 7,
#     'distanceFromRoadSectionStart': 42,
#     'carriagewayCode': 0,
#     'roadMaintenanceClass': '4',
#     'contractArea': 'Kotka 13 - 20',
#     'contractAreaCode': 386,
#     'carriageway': 'ONE_CARRIAGEWAY'},
#    'liviId': 'Livi1089855',
#    'country': None,
#    'startTime': '2012-05-31T21:00:00Z',
#    'repairMaintenanceTime': '2019-02-21T12:24:28Z',
#    'annualMaintenanceTime': '2018-09-24T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [555017.0, 6739779.0, 0.0],
#    'presets': [{'presetId': 'C0358001',
#      'cameraId': 'C03580',
#      'presentationName': 'Vaalimaalle',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0358001.jpg',
#      'direction': 'INCREASING_DIRECTION'},
#     {'presetId': 'C0358002',
#      'cameraId': 'C03580',
#      'presentationName': 'Lappeenrantaan',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '2',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0358002.jpg',
#      'direction': 'DECREASING_DIRECTION'},
#     {'presetId': 'C0358009',
#      'cameraId': 'C03580',
#      'presentationName': 'Tienpinta',
#      'inCollection': True,
#      'resolution': '1280x720',
#      'directionCode': '9',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0358009.jpg',
#      'direction': 'SPECIAL_DIRECTION'}],
#    'nearestWeatherStationId': 5014}},
#  '3644': {'timestamp': '2019-02-26T09:33:37Z',
#   'roadStationId': {'roadStationId': 3644,
#    'id': 'C03644',
#    'name': 'vt13_Nuijamaa_HLK',
#    'cameraType': 'VAPIX',
#    'collectionInterval': 300,
#    'collectionStatus': 'GATHERING',
#    'municipality': 'Lappeenranta',
#    'municipalityCode': '405',
#    'province': 'Etelä-Karjala',
#    'provinceCode': '9',
#    'names': {'fi': 'Tie 13 Lappeenranta, Nuijamaa'},
#    'roadAddress': {'roadNumber': 13,
#     'roadSection': 241,
#     'distanceFromRoadSectionStart': 5500},
#    'liviId': 'KAMM1341',
#    'country': None,
#    'startTime': '2016-11-15T13:32:12Z',
#    'repairMaintenanceTime': '2017-02-14T08:39:20Z',
#    'annualMaintenanceTime': '2018-10-09T21:00:00Z',
#    'state': 'OK',
#    'purpose': 'keli',
#    'coordinatesETRS89': [581688.0, 6759428.0, 0.0],
#    'presets': [{'presetId': 'C0364401',
#      'cameraId': 'C03644',
#      'presentationName': 'lähtevä liikenne',
#      'inCollection': True,
#      'resolution': '704x576',
#      'directionCode': '1',
#      'imageUrl': 'http://weathercam.digitraffic.fi/C0364401.jpg',
#      'direction': 'INCREASING_DIRECTION'}],
#    'nearestWeatherStationId': 3012}}}

# %%
with open('camera_station_LPR.json', 'w') as fp:
    json.dump(camera_stations, fp)

# %%
r=requests.get(url='https://tie.digitraffic.fi/api/v1/data/road-conditions?lastUpdated=false')

# %%
print(r.json())
# Out:
# {'dataUpdatedTime': '2019-03-22T13:01:22Z', 'weatherData': [{'id': '00009_303_000_0', 'roadConditions': [{'time': '2019-03-22T12:50:00Z', 'type': 'OBSERVATION', 'forecastName': '0h', 'daylight': True, 'roadTemperature': '+10.4', 'temperature': '+4.5', 'windSpeed': 3.5, 'windDirection': 308, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd000', 'reliability': 'SUCCESSFUL'}, {'time': '2019-03-22T14:00:00Z', 'type': 'FORECAST', 'forecastName': '2h', 'daylight': True, 'roadTemperature': '10', 'temperature': '4', 'windSpeed': 4.0, 'windDirection': 308, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd000', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'DRY'}}, {'time': '2019-03-22T16:00:00Z', 'type': 'FORECAST', 'forecastName': '4h', 'daylight': True, 'roadTemperature': '+3', 'temperature': '+1', 'windSpeed': 2.0, 'windDirection': 301, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd000', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'DRY'}}, {'time': '2019-03-22T18:00:00Z', 'type': 'FORECAST', 'forecastName': '6h', 'daylight': False, 'roadTemperature': '+0', 'temperature': '-2', 'windSpeed': 2.0, 'windDirection': 253, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'n100', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'DRY'}}, {'time': '2019-03-23T00:00:00Z', 'type': 'FORECAST', 'forecastName': '12h', 'daylight': False, 'roadTemperature': '-2', 'temperature': '-2', 'windSpeed': 4.0, 'windDirection': 188, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'n400', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'DRY'}}]}, {'id': '00028_038_000_0', 'roadConditions': [{'time': '2019-03-22T12:51:00Z', 'type': 'OBSERVATION', 'forecastName': '0h', 'daylight': True, 'roadTemperature': '+1.2', 'temperature': '+2.9', 'windSpeed': 4.8, 'windDirection': 282, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd010', 'reliability': 'SUCCESSFUL'}, {'time': '2019-03-22T14:00:00Z', 'type': 'FORECAST', 'forecastName': '2h', 'daylight': True, 'roadTemperature': '1', 'temperature': '3', 'windSpeed': 5.0, 'windDirection': 282, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd010', 'reliability': 'NO_DATA_FROM_ROADSTATION'}, {'time': '2019-03-22T16:00:00Z', 'type': 'FORECAST', 'forecastName': '4h', 'daylight': True, 'roadTemperature': '+3', 'temperature': '0', 'windSpeed': 1.0, 'windDirection': 267, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd000', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'DRY'}}, {'time': '2019-03-22T18:00:00Z', 'type': 'FORECAST', 'forecastName': '6h', 'daylight': False, 'roadTemperature': '-1', 'temperature': '-4', 'windSpeed': 2.0, 'windDirection': 198, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'n100', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'DRY'}}, {'time': '2019-03-23T00:00:00Z', 'type': 'FORECAST', 'forecastName': '12h', 'daylight': False, 'roadTemperature': '-2', 'temperature': '-1', 'windSpeed': 6.0, 'windDirection': 187, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'n400', 'reliability': 'NO_DATA_FROM_ROADSTATION', 'forecastConditionReason': {'roadCondition': 'DRY'}}]}, {'id': '00001_019_000_0', 'roadConditions': [{'time': '2019-03-22T12:54:00Z', 'type': 'OBSERVATION', 'forecastName': '0h', 'daylight': True, 'roadTemperature': '+14.6', 'temperature': '+5.7', 'windSpeed': 4.6, 'windDirection': 311, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbol': 'd000', 'reliability': 'SUCCESSFUL'}, {'time': '2019-03-22T14:00:00Z', 'type': 'FORECAST', 'forecastName': '2h', 'daylight': True, 'roadTemperature': '15', 'temperature': '6', 'windSpeed': 5.0, 'windDirection': 311, 'overallRoadCondition': 'NORMAL_CONDITION', 'weatherSymbo ...

# %%
roads = r.json()

# %%
roads['dataUpdatedTime']
# Out:
# '2019-03-21T15:24:45Z'

# %%
relevant_roads = {'00013', '00006'}

# %%
roads = r.json()
counter = 0
road_conditions = {}

for i in roads['weatherData']:
    road_number = i['id'].split('_')[0]
    road_section = i['id'].split('_')[1]
    if road_number == "00006" or road_number == "00013":
        road_conditions[road_number + '_' +  road_section] = {"roadConditions": i["roadConditions"]}

# %%
len(road_conditions)
# Out:
# 26
